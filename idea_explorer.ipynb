# %% [markdown]
# first the user will describe an idea -> llm -> llm will think about the idea and choose appropriate tool to research about the idea
#
# a generalised idea researcher the does an indept research about a certain startup idea by doing sentiment analysis on social media
# ##### tools:
# 1. InDepth idea visualisation by an llm
# 2. reddit sentiment analysis
# 3. web search on the idea

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langgraph.graph import StateGraph, END, START
from langgraph.graph.message import add_messages
from typing_extensions import TypedDict, Annotated, Literal
from langchain.messages import AnyMessage

# %%
class State(TypedDict):
    messages:Annotated[list[AnyMessage], add_messages]

# %%
@tool
def webSearch()
